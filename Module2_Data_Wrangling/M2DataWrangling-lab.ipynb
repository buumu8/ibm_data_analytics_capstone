# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %% [markdown]
# The functions below will download the dataset into your browser:

# %%
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv"

# %% [markdown]
# To obtain the dataset, utilize the download() function as defined above:

# %%
await download(file_path, "m1_survey_data.csv")
file_name="m1_survey_data.csv"

# %% [markdown]
# Utilize the Pandas method read_csv() to load the data into a dataframe.

# %%
df = pd.read_csv(file_name)

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
print(len(df[df.duplicated()==True]))
print(len(df[df['Respondent'].duplicated()==True]))
# Out:
# 154
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df = df.drop_duplicates()

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
df['Respondent']
# Out:
# 0            4
# 1            9
# 2           13
# 3           16
# 4           17
#          ...
# 11547    25136
# 11548    25137
# 11549    25138
# 11550    25141
# 11551    25142
# Name: Respondent, Length: 11398, dtype: int64

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
print(len(df[df['EdLevel'].isna() == True]))
print(len(df[df['Country'].isna() == True]))
# Out:
# 112
# 0

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
print(len(df[df['WorkLoc'].isna() == True]))
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df['WorkLoc'].value_counts()
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
#Office

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df['WorkLoc'].fillna('Office', inplace = True)
# Out:
# <ipython-input-46-e40a51a50ca6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WorkLoc'].fillna('Office', inplace = True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
print(df['WorkLoc'].value_counts())
print(len(df[df['WorkLoc'].isna() == True]))
# Out:
# Office                                            6838
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here
list = []

for _, row in df.iterrows():
    if row['CompFreq'] == 'Yearly':
        list.append(row['CompTotal'])
    elif row['CompFreq'] == 'Monthly':
        list.append(row['CompTotal'] * 12)
    else:
        list.append(row['CompTotal'] * 52)
        
df = df.assign(
# Out:
# [61000.0, 138000.0, 90000.0, 348000.0, 90000.0, 114000.0, 36000.0, 103000.0, 69000.0, 96000.0, 84000.0, 114000.0, 104000.0, 1144000.0, 1152000.0, 156000.0, 18000.0, 76800.0, 60000.0, 400000.0, 47300.0, 618000.0, 345000.0, 85000.0, 107000.0, 66000.0, 76800.0, 50000.0, 800000.0, 75000.0, 216000.0, 100000.0, 1250000.0, 30000.0, 550000.0, nan, 8400000.0, 480000.0, 108000.0, 132000.0, 1200000.0, 50000.0, 33000.0, 110000.0, 66750.0, 300000.0, 3525600.0, 155000.0, 300000.0, 100000.0, nan, 70000.0, 360000.0, 90000.0, 26000.0, 31000.0, nan, 288000.0, 650000.0, 60000.0, 1272000.0, 62000.0, 48000.0, 2107200.0, 70000.0, 540000.0, 48000.0, 642000.0, 135000.0, 48000.0, 840000.0, 960000.0, 41232.0, 50000.0, 384000000.0, 48000.0, 7124000.0, 68000.0, 144000.0, nan, 50000.0, 70000.0, 84000.0, 13000000.0, 35000.0, 50000.0, 480000.0, 90000.0, 90000.0, 108000.0, 48000.0, 39000.0, 44400.0, 95000.0, 450000.0, 112800.0, 117800.0, 17400.0, 180000.0, 100000.0, 48000.0, 110000.0, nan, 420000.0, 233000.0, nan, 80000.0, 120000.0, 496800.0, 2000000.0, 86000.0, 5880000.0, 88000.0, 50400.0, 240000.0, 45000.0, 52000.0, 180000.0, 600000.0, 180000.0, 864000.0, 3200000.0, nan, 2196000.0, 130000.0, 288000.0, 1560000.0, 55000.0, 0.0, nan, 360000.0, 540000.0, 130000.0, 115000.0, 0.0, nan, 63000.0, 66000.0, nan, 123000.0, 140000.0, 43200.0, 360000.0, 160000.0, 84000.0, 109200.0, nan, 140000.0, 105000.0, 30000.0, 19000.0, 360000.0, 48000.0, 5280000.0, 57000.0, 3000000.0, 312000.0, 468000.0, 55000.0, 744000.0, 41016.0, 170000.0, 48000.0, 125000.0, 151200.0, 1884000.0, 55000.0, 100000.0, nan, 36000.0, 6750000.0, 104000.0, 23800.0, 30000.0, 140